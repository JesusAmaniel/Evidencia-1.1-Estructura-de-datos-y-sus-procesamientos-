# %%
import time

segundos = int (input("cantidad de segundos a esperar:\n"))
time.sleep(segundos) #Esperar por lo menos la cantidad de segundos especificada
print(f"Han trascurido, por lo menos{segundos}segundos")
# Out:
# cantidad de segundos a esperar:
# 2
# Han trascurido, por lo menos2segundos

# %%
HoraInicial = time.time()

for termino in range(10):
  time.sleep(segundos)
print("proceso simulado concluido")
duracion = time.time()- HoraInicial #Puede verse afectado si se cambia la hora del sistema
print(f"La duracion del proceso simulado fue de {duracion:4f}segundos")
# Out:
# proceso simulado concluido
# La duracion del proceso simulado fue de 20.001861segundos
