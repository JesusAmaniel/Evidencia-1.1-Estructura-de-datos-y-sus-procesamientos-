# %%
import datetime
import time
#Creacion de una hora especifica
hora= datetime.time(10,20,30)
print(f"El tipo de objetivo de la hora es {type(hora)}")
print(f"La hora es{hora}")
print(f"La hora de {hora} es {hora.hour}") #limitado 0.23
print(f"El minuto de {hora} es {hora.minute}") #limitado 0..59
print(f"El segundo de {hora} es {hora.second}")# limitado 0..59
print(f"El microsegundo de { hora} es {hora.microsecond}")#limitado 0..999999
# Out:
# El tipo de objetivo de la hora es <class 'datetime.time'>
# La hora es10:20:30
# La hora de 10:20:30 es 10
# El minuto de 10:20:30 es 20
# El segundo de 10:20:30 es 30
# El microsegundo de 10:20:30 es 0

# %%
#Determinar la fecha del sistema
fecha_actual= datetime.date.today()
print(f"El tipo de objetivo de la fecha es {type(fecha_actual)}")
print(f"La fecha actual es {fecha_actual}")
print(f"El año actual es {fecha_actual.year}")
print(f"El mes actual es {fecha_actual.month}")
print(f"El dia actual es {fecha_actual.day}")
# Out:
# El tipo de objetivo de la fecha es <class 'datetime.date'>
# La fecha actual es 2026-08-08
# El año actual es 2026
# El mes actual es 8
# El dia actual es 8

# %%
#Si se le propociona una fecha imposible, o en un formato invalido se producira un error
fecha_actual= input ("Dime una fecha (dd/mm/aaaa):\n")
fecha_procesada = datetime.datetime.strptime(fecha_actual, "%d/%m/%Y").date()
print(type(fecha_capturada)
print(type(fecha_procesada))
print(fecha_procesada

# %%
print(f"De entrada, tenemos el valor {fecha_procesada}en la variable con el tipo de dato especializado\n")

print(f"El mismo valor lo puede presentar en el formato dd/dd/aaaa:{fecha_procesada.strftime}")

# %%
cant_dias = int(input(f"Dime la cantidad de dias a adelante respecto a {fecha_procesada}:\n"))
nueva_fecha = fecha_procesada + datetime.timedelta (days+cant_dias)
print(f"La nueva fecha es {nueva_fecha}")
