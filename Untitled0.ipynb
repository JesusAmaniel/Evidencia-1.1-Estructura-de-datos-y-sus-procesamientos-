# %%
import random

print (f"Obtener un numero aleatorio que puede ir del 0 al 19:{random.randrage(20)}")

print(f"Obtener un nuevo entero entre aleatorio para que puede ir del 2 al 20:{random.randrage(2,21,2)}")

print (f"Obtener un nuevo entero aleatorio que puede ir del 1 hasta el 20: {random.randint(1,28)}")

print

# %%
listaDePrueba = [10,20,30,40,15,25,35,45]
print(f"La lista de prueba es{listaDePrueba}")

print(f"El valor selecionado aleatoriamente de la lista anterior es{random.choice(listaDePrueba)}")

random.shuffle(listaDePrueba)
print(f"La lista ya ‘perturbada/barajada’es {listaDePrueba}")
# Out:
# La lista de prueba es[10, 20, 30, 40, 15, 25, 35, 45]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1281/361800550.py in <cell line: 0>()
#       2 print(f"La lista de prueba es{listaDePrueba}")
#       3
# ----> 4 print(f"El valor selecionado aleatoriamente de la lista anterior es{random.choice(listaDePrueba)}")
#       5
#       6 random.shuffle(listaDePrueba)
#
# NameError: name 'random' is not defined
